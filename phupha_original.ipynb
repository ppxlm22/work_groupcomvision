# %%
import cv2
import numpy as np

# %%
cv2.namedWindow("HSV Tuner", cv2.WINDOW_NORMAL)

cv2.createTrackbar("H Low",  "HSV Tuner", 0,   179, lambda x: None)
cv2.createTrackbar("H High", "HSV Tuner", 179, 179, lambda x: None)
cv2.createTrackbar("S Low",  "HSV Tuner", 0,   255, lambda x: None)
cv2.createTrackbar("S High", "HSV Tuner", 255, 255, lambda x: None)
cv2.createTrackbar("V Low",  "HSV Tuner", 0,   255, lambda x: None)
cv2.createTrackbar("V High", "HSV Tuner", 255, 255, lambda x: None)

# %%
img = cv2.imread("D:\\year3term2\\vision\\ch5\\img\\picture1.png")
if img is None:
    print("ไม่พบไฟล์ภาพ")
    exit()

# %%
while True:
    frame = img.copy()

    h_low  = cv2.getTrackbarPos("H Low",  "HSV Tuner")
    h_high = cv2.getTrackbarPos("H High", "HSV Tuner")
    s_low  = cv2.getTrackbarPos("S Low",  "HSV Tuner")
    s_high = cv2.getTrackbarPos("S High", "HSV Tuner")
    v_low  = cv2.getTrackbarPos("V Low",  "HSV Tuner")
    v_high = cv2.getTrackbarPos("V High", "HSV Tuner")

    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    lower = np.array([h_low, s_low, v_low])
    upper = np.array([h_high, s_high, v_high])

    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(frame, frame, mask=mask)

    result = cv2.erode(result, None, iterations=1)
    result = cv2.dilate(result, None, iterations=1)

    mask_3ch = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

    top = np.hstack((frame, hsv))
    bottom = np.hstack((mask_3ch, result))
    combined = np.vstack((top, bottom))

    cv2.imshow("HSV Tuner", combined)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 4
#       1 while True:
#       2     frame = img.copy()
# ----> 4     h_low  = cv2.getTrackbarPos("H Low",  "HSV Tuner")
#       5     h_high = cv2.getTrackbarPos("H High", "HSV Tuner")
#       6     s_low  = cv2.getTrackbarPos("S Low",  "HSV Tuner")
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2570: error: (-27:Null pointer) NULL window: 'HSV Tuner' in function 'cvGetTrackbarPos'
